# %%
## Import Labraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Part 1 - Data Gathering (Multiple Sources)

# %% [markdown]
# ### Task 1: Load Data from CSV

# %%
# Load the dataset

data=pd.read_csv('netflix_titles.csv')

# %%
# Print Shape of the dataset

data.shape
# Out:
# (8807, 12)

# %%
# Print index of the dataset
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Print first 5 rows of the dataset
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
# Print last 5 rows of the dataset
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# Type of the dataset
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# Print information like number of rows , columns, data types, memory usage
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Print summary statistics of the dataset
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# ### Task 2: Load Data from JSON

# %%
# Load using pandas
product=pd.read_json('product_data.json')

# %%
## Convert into a DataFrame

product_df=pd.DataFrame(product)

# %%
### print dataframe

product_df
# Out:
#      product_id     category            brand  season  size  color  \
# 0      FB000001    Outerwear             Zara  Spring    XL    Red
# 1      FB000002         Tops           Uniqlo  Winter     L   Pink
# 2      FB000003  Accessories           Uniqlo  Winter  None  Black
# 3      FB000004        Shoes           Uniqlo  Spring    XL  Black
# 4      FB000005         Tops  Banana Republic  Winter    XL  Black
# ...         ...          ...              ...     ...   ...    ...
# 2171   FB002172         Tops            Mango  Summer    XL  Black
# 2172   FB002173      Dresses  Banana Republic  Winter     L  Brown
# 2173   FB002174  Accessories  Banana Republic  Winter  None  Beige
# 2174   FB002175      Bottoms       Ann Taylor  Summer    XL   Pink
# 2175   FB002176        Shoes       Ann Taylor  Summer   XXL  White
#
#       original_price  markdown_percentage  current_price  \
# 0             196.01                  0.0         196.01
# ...

# %% [markdown]
# ### Task 3: Load Data from SQL Database

# %%
# import library

import sqlite3

# %%
## Create a SQLite database

details=sqlite3.connect('sample.db')
cursor=details.cursor()

# %%
### Create a table employes

cursor.execute("""
CREATE TABLE IF NOT EXISTS employees (
    id INTEGER PRIMARY KEY,
    name TEXT,
    department TEXT,
    salary INTEGER
)
""")

# %%
### Insert 5 Records

employees=[
    (1, "Sunil","CTO",90000),
    (2, "Rahul","HR",45000),
    (3, "Priyanshi","IT",60000),
    (4, "Ranjeet","Marketing",43000),
    (5, "Shivam","Finance",56000)
]

cursor.executemany("INSERT OR REPLACE INTO employees VALUES(?,?,?,?)",employees)
details.commit()

# %%
#### Read the table into pandas

df=pd.read_sql_query('SELECT * FROM employees',details)

# %%
##### Display the dataframe
df
# Out:
#    id       name department  salary
# 0   1      Sunil        CTO   90000
# 1   2      Rahul         HR   45000
# 2   3  Priyanshi         IT   60000
# 3   4    Ranjeet  Marketing   43000
# 4   5     Shivam    Finance   56000

# %% [markdown]
# ### Task 4: API Mini Project(TMDB API)
#
# ### Mini Project : Movie Data Collector

# %%
import requests

# %%
# API for Popular Movies from TMDB

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MmYwYjM5YzEwYjdlZjhkOWY0ZTE4NDcwYmY5ZWI0NiIsIm5iZiI6MTc4NTU1NTI1MS4zNjUsInN1YiI6IjZhNmQ2OTMzYjhiZmVkYmY4MzU0MzU1ZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.p5LWELCB_bmkk1SzgAgNv6Yzy7EQ7o46PT-knVfQnjA"
}

response = requests.get(url=url, headers=headers)

print(response)
# Out:
# <Response [200]>

# %%
# Convert into DataFrame

df=pd.DataFrame(response.json()['results'])

# %%
df.head()
# Out:
#    adult                     backdrop_path      genre_ids       id  \
# 0  False  /qeQJx07rK2xm8SD2sJxFKhE7gs0.jpg  [878, 28, 12]   969681
# 1  False  /sSIzzVhhLfgLKVBcAUv0X6cLYz9.jpg   [12, 28, 14]  1368337
# 2  False  /4X2YSe8PaYbsBqX3TDmmIU4vOju.jpg  [28, 12, 878]  1081003
# 3  False  /14QbnygCuTO0vl7CAFmPf1fgZfV.jpg  [28, 12, 878]   634649
# 4  False  /yQIdU11DYQQp0neGtGtGxbGfRer.jpg  [28, 14, 878]   454639
#
#                        title original_language             original_title  \
# 0  Spider-Man: Brand New Day                en  Spider-Man: Brand New Day
# 1                The Odyssey                en                The Odyssey
# 2                  Supergirl                en                  Supergirl
# 3    Spider-Man: No Way Home                en    Spider-Man: No Way Home
# 4    Masters of the Universe                en    Masters of the Universe
#
#                                             overview  popularity  \
# ...

# %%
# Remove extra columns

df=df[['adult','id','title','overview','popularity','release_date','vote_count','vote_average']]

# %%
df.shape
# Out:
# (20, 8)

# %%
# Make a empty dataframe to store the films data from loop

Final_Data=pd.DataFrame()

for i in range(1,501):
    url = f"https://api.themoviedb.org/3/movie/popular?language=en-US&page={i}".format(i)

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MmYwYjM5YzEwYjdlZjhkOWY0ZTE4NDcwYmY5ZWI0NiIsIm5iZiI6MTc4NTU1NTI1MS4zNjUsInN1YiI6IjZhNmQ2OTMzYjhiZmVkYmY4MzU0MzU1ZiIsInNjb3BlcyI6WyJhcGxfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.p5LWELCB_bmkk1SzgAgNv6Yzy7EQ7o46PT-knVfQnjA"
    }

    response = requests.get(url=url, headers=headers)

    df=df[['adult','id','title','overview','popularity','release_date','vote_count','vote_average']]

    Final_Data=pd.concat([Final_Data,df], ignore_index=False)

# %%
Final_Data.to_csv('tmdb_movies.csv',index=False)

# %%
# Final shape of dataset which extract from tmdb database
Final_Data.shape
# Out:
# (10000, 8)

# %% [markdown]
# # Part 2 - Data Preprocessing & Cleaning

# %% [markdown]
# ### Task 5: Understanding the Data

# %%
# Netflix dataset top 5 rows
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# 1. Check dataset shape
data.shape
# Out:
# (8807, 12)

# %%
# 2. Display column data types
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# 3. Identify numerical Columns
data.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['release_year'], dtype='object')

# %%
# Identify categorical columns
data.select_dtypes(include=['object']).columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# 4. Check missing values count per column
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Total missing values
data.isnull().sum().sum()
# Out:
# np.int64(4307)

# %%
# Duplicate rows
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Statistical summary
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# ### Task 6: Data Cleaning

# %%
# 1. Checking the missing value
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#### Fill numerical missing values with median

numerical_cols=data.select_dtypes(include=['int64']).columns

for col in numerical_cols:
    data[col]=data[col].fillna(data[col].median())

# %%
#### Fill categorical missing values with Unknown

categorical_cols=data.select_dtypes(include=['object']).columns

for col in categorical_cols:
    data[col]=data[col].fillna('Unknown')

# %%
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# 2. Remove duplicate rows --> there is now duplicated rows

data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Rename columns to lowercase

data.columns=(data.columns.str.strip().str.lower().str.replace(" ","_"))
print(data.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data['date_added']=pd.to_datetime(data['date_added'],errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8709 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %% [markdown]
# ### Task 7: Feature Preparation(Basic)

# %%
data.head()
# Out:
#   show_id     type                  title         director        country  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s2  TV Show          Blood & Water              NaN   South Africa
# 2      s3  TV Show              Ganglands  Julien Leclercq            NaN
# 3      s4  TV Show  Jailbirds New Orleans              NaN            NaN
# 4      s5  TV Show           Kota Factory              NaN          India
#
#    release_year rating                                          listed_in  \
# 0          2020  PG-13                                      Documentaries
# 1          2021  TV-MA    International TV Shows, TV Dramas, TV Mysteries
# 2          2021  TV-MA  Crime TV Shows, International TV Shows, TV Act...
# 3          2021  TV-MA                             Docuseries, Reality TV
# 4          2021  TV-MA  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# ...

# %%
## Selection of columns

data=data[['show_id','type','title','director','country','release_year','rating','listed_in','description']]

# %%
# 1. Convert categorical columns into numerical

# %%
## Label Encoding

from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

# %%
data['type_label']=le.fit_transform(data['type'])

# %%
data[['type','type_label']].head()
# Out:
#       type  type_label
# 0    Movie           0
# 1  TV Show           1
# 2  TV Show           1
# 3  TV Show           1
# 4  TV Show           1

# %%
## One Hot encoding

rating_encoded=pd.get_dummies(data['rating'],prefix='rating')

# %%
rating_encoded
# Out:
#       rating_66 min  rating_74 min  rating_84 min  rating_G  rating_NC-17  \
# 0             False          False          False     False         False
# 1             False          False          False     False         False
# 2             False          False          False     False         False
# 3             False          False          False     False         False
# 4             False          False          False     False         False
# ...             ...            ...            ...       ...           ...
# 8802          False          False          False     False         False
# 8803          False          False          False     False         False
# 8804          False          False          False     False         False
# 8805          False          False          False     False         False
# 8806          False          False          False     False         False
#
#       rating_NR  rating_PG  rating_PG-13  rating_R  rating_TV-14  rating_TV-G  \
# ...

# %%
# 2. Separate features and target column

X=data[['show_id','title','director','country','release_year','rating','listed_in','description']]
Y=data['type']

# %%
# Print X
X
# Out:
#      show_id                  title         director        country  \
# 0         s1   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1         s2          Blood & Water              NaN   South Africa
# 2         s3              Ganglands  Julien Leclercq            NaN
# 3         s4  Jailbirds New Orleans              NaN            NaN
# 4         s5           Kota Factory              NaN          India
# ...      ...                    ...              ...            ...
# 8802   s8803                 Zodiac    David Fincher  United States
# 8803   s8804            Zombie Dumb              NaN            NaN
# 8804   s8805             Zombieland  Ruben Fleischer  United States
# 8805   s8806                   Zoom     Peter Hewitt  United States
# 8806   s8807                 Zubaan      Mozez Singh          India
#
#       release_year rating                                          listed_in  \
# ...

# %%
# Print Y
Y
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object

# %% [markdown]
# ## Part 3 - Explortory Data Analysis (EDA)

# %% [markdown]
# ### Task 8: Univariate Analysis

# %%
data.head()
# Out:
#   show_id     type                  title         director        country  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s2  TV Show          Blood & Water              NaN   South Africa
# 2      s3  TV Show              Ganglands  Julien Leclercq            NaN
# 3      s4  TV Show  Jailbirds New Orleans              NaN            NaN
# 4      s5  TV Show           Kota Factory              NaN          India
#
#    release_year rating                                          listed_in  \
# 0          2020  PG-13                                      Documentaries
# 1          2021  TV-MA    International TV Shows, TV Dramas, TV Mysteries
# 2          2021  TV-MA  Crime TV Shows, International TV Shows, TV Act...
# 3          2021  TV-MA                             Docuseries, Reality TV
# 4          2021  TV-MA  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  type_label
# ...

# %%
# Plot distribution of numerical columns

sns.histplot(data=data,x='release_year',kde=True)
plt.title('Distribution of Release Year')
plt.show()

# %%
# Count plot for categorical columns

sns.countplot(data=data,x='type')
plt.title('Count plot of type')
plt.show()

# %%
data['country'].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
country=data[data['country'].isin(['United States','India','Unknown','United Kingdom','Japan','South Korea','Canada','Spain','France','Mexico'])]

# %%
sns.countplot(data=country,x='country')
plt.title('Top 10 Countries')
plt.xticks(rotation='vertical')
plt.show()

# %%
data['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
director=data[data['director'].isin(['Rajiv Chilaka','Raúl Campos, Jan Suter','Suhas Kadav','Marcus Raboy','Jay Karas','Cathy Garcia-Molina','Jay Chapman','Youssef Chahine','Martin Scorsese'])]

# %%
sns.countplot(data=director,x='director')
plt.title('Top 10 Directors')
plt.xticks(rotation='vertical')
plt.show()

# %%
# Identify outliers using boxplot

sns.boxplot(data=data,x='release_year')
plt.title('Boxplot for Release Year')
plt.show()

# %%
sns.boxplot(data=director,x='director')
plt.title('Boxplot for Director')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.boxplot(data=country,x='country')
plt.title('Boxplot for Country')
plt.xticks(rotation='vertical')
plt.show()

# %%
# Show Every Chart Possible
sns.violinplot(data=data,x='release_year')
plt.title('Voilin plot for Release Year')
plt.show()

# %%
sns.rugplot(data=data,x='release_year')
plt.title('Rugplot for Release Year')
plt.show()

# %%
sns.stripplot(data=data,x='release_year')
plt.title('Stripplot for Release Year')
plt.show()

# %% [markdown]
# ### Task 9: Bivariate Analysis

# %%
# Numerical vs Numerical
sns.scatterplot(data=data,x='type',y='release_year')
plt.show()

# %%
corr=data.corr(numeric_only=True)

sns.heatmap(corr,annot=True,cmap='Blues')
plt.title('Correlation heatmap')
plt.show()

# %%
# Categorical vs Numerical

sns.barplot(data=data,x='type',y='release_year')
plt.title('Average Release Year by type')
plt.show()

# %%
sns.boxplot(data=data,x='type',y='release_year')
plt.title('Release year by type')
plt.show()

# %%
sns.violinplot(data=data,x='rating',y='release_year')
plt.title('Rating the Release year')
plt.xticks(rotation='vertical')
plt.show()

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'release_year',
#        'rating', 'listed_in', 'description', 'type_label'],
#       dtype='object')

# %%
sns.pointplot(data=data,x='type',y='release_year')
plt.title('Release Year Vs Type')
plt.show()

# %% [markdown]
# ### Task 10: Insights & Observations
#
# 1. Most Netflix titles were released after 2015
# 2. Movies are most common than TV shows
# 3. The United States has the highest number of titles
# 4. Older release year appear as outliers in the box plot
# 5. Most content is concentrated between 2015 and 2021
# 6. Missing values were cleaned successfully
# 7. The final dataset is clean and ready for analysis
