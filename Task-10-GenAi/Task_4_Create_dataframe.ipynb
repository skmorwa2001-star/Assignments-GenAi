# %% [markdown]
# ## Task 4: Create a DataFrame

# %%
import pandas as pd

# %%
# Create dictionary dataset

students={
    'Name':['Amit','Neha','Rahul','Sneha','Pooja'],
    'Marks':[78, 85, 90, 66, 72],
    'Subject':['Math','Math','Science','Science','Math']
}

# %%
# 1. Convert into a dataframe

students = pd.DataFrame(students)

# %%
students
# Out:
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1   Neha     85     Math
# 2  Rahul     90  Science
# 3  Sneha     66  Science
# 4  Pooja     72     Math

# %%
# 2. Print first 3 rows

students.head(3)
# Out:
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1   Neha     85     Math
# 2  Rahul     90  Science

# %%
# 3. Print last 2 rows


students.tail(2)
# Out:
#     Name  Marks  Subject
# 3  Sneha     66  Science
# 4  Pooja     72     Math

# %%
# Print DataFrame shape and columns names

students.shape
# Out:
# (5, 3)

# %%
students.columns
# Out:
# Index(['Name', 'Marks', 'Subject'], dtype='object')
